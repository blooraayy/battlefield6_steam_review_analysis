# %% [markdown]
# Verificar datos en crudo

# %%
import pandas as pd
# Directorio del csv
df_raw = pd.read_csv("../data/pragmata_reviews_raw.csv")

# %%
# Imprimir total de reseñas en ingles
print(df_raw["language"].value_counts())
# Out:
# language
# english    16565
# Name: count, dtype: int64

# %%
# Imprimir tipos de reseñas
print(df_raw["voted_up"].value_counts())
# Out:
# voted_up
# True     16167
# False      398
# Name: count, dtype: int64

# %% [markdown]
# Verificar datos procesados

# %%
import pandas as pd
# Directorio del csv
df_clean = pd.read_csv("../data/pragmata_reviews_clean.csv")

# %%
# Imprimir total de reseñas en ingles
print(df_raw["language"].value_counts())
# Out:
# language
# english    16565
# Name: count, dtype: int64

# %%
# Imprimir tipos de reseñas
print(df_raw["voted_up"].value_counts())
# Out:
# voted_up
# True     16167
# False      398
# Name: count, dtype: int64
